# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
MG = np.random.randn(20).reshape((4,5))
MG
# Out:
# array([[-0.29438421, -0.94771583,  0.43284357,  0.52758661,  0.16072314],
#        [-0.66939758,  0.06015598, -0.51751999,  1.05955713,  0.26462324],
#        [-1.67573544, -0.70058035, -0.46343698, -1.30571335, -0.98891241],
#        [ 1.27642761, -1.78323669, -0.20508375, -1.59451415,  1.04613607]])

# %%
plt.plot(MG)
